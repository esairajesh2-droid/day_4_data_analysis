# %%
#importing the dataset and required libraries
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\esair\OneDrive\Desktop\thelast\fifa_world_cup_2026_player_performance.csv")

# %%
df['position'].value_counts()
# Out:
# position
# Defender      18900
# Midfielder    16800
# Forward       12600
# Goalkeeper     6300
# Name: count, dtype: int64

# %%
goalkeepers = df[df['position'] == 'Goalkeeper']

# %%
s=goalkeepers['player_name'].value_counts().head(5)
# Out:
# player_name
# Akram Ali         66
# Hassan Abdulla    66
# Almoez Boudiaf    66
# Leon Antonio      59
# Michail Gray      59
# Name: count, dtype: int64
